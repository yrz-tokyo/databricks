# %% [markdown]
# 今回のハンズオンに、Serverlessタイプのコンピュート（Databricksフルマネージド）を利用します。<br>
# Classicタイプのコンピュートは対象外です。<br>
# ### ノートブックに利用できるServerlessタイプのコンピュート：<br>
# - Serverless SQL Warehouse（先ほど作成されたもの）：SQL向けに最適化されたDatabricksフルマネージドのコンピュート
# - Serverless：プラットフォーム全体の汎用的なDatabricksフルマネージドのコンピュート
#
# ### ハンズオンステップ：
# １、Serverless SQL Warehouseで、SQLでhello worldを表示します。<br>
# ２、Serverless SQL Warehouseで、Pythonでhello worldを表示します。<br>
# ３、Serverlessで、Pythonでhello worldを表示します。<br>
# ４、Serverlessで、SQLでhello worldを表示します。

# %%
# %sql
--  SQLでhello worldを表示するコードをください
SELECT 'hello world'

# %%
# pythonでhello worldを表示するコードをください
print("Hello World!")
